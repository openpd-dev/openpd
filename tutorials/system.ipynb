# %%
import sys, os
sys.path.append('..')
import openpd as pd
import openpd.unit as unit

# %% [markdown]
# # PDBLoader

# %%
pdb_file = './data/demo.pdb'

loader = pd.PDBLoader(pdb_file)
system = loader.createSystem()

visualizer = pd.SystemVisualizer(system)
visualizer.show()

# %%
pdb_file = './data/demo.pdb'

loader = pd.PDBLoader(pdb_file)
system = loader.createSystem(is_extract_coordinate=False)

visualizer = pd.SystemVisualizer(system)
visualizer.show()

# %% [markdown]
# # SequenceLoader

# %%
sequence_file = './data/sequence.json'

loader = pd.SequenceLoader(sequence_file)
system = loader.createSystem()

visualizer = pd.SystemVisualizer(system)
visualizer.show()
